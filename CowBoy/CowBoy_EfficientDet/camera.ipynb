# %%
import time
import torch
from torch.backends import cudnn
from matplotlib import colors
import cv2
import numpy as np

from backbone import EfficientDetBackbone
from efficientdet.utils import BBoxTransform, ClipBoxes
from utils.utils import postprocess, STANDARD_COLORS, standard_to_bgr, get_index_label, plot_one_box

compound_coef = 0
force_input_size = None  # set None to use default size

# Camera setup
cap = cv2.VideoCapture(0)  # 0 for the default camera, or you can use the index for an external camera
if not cap.isOpened():
    print("Error: Could not open webcam.")
    exit()

# Replace this part with your project's anchor config
anchor_ratios = [(1.0, 1.0), (1.4, 0.7), (0.7, 1.4)]
anchor_scales = [2 ** 0, 2 ** (1.0 / 3.0), 2 ** (2.0 / 3.0)]

threshold = 0.2
iou_threshold = 0.2

use_cuda = True
use_float16 = False
cudnn.fastest = True
cudnn.benchmark = True

obj_list = ['belt', 'sunglasses', 'boot', 'cowboy_hat', 'jacket']
# obj_list = ['person', 'bicycle', 'car', 'motorcycle', 'airplane', 'bus', 'train', 'truck', 'boat', 'traffic light',
#             'fire hydrant', '', 'stop sign', 'parking meter', 'bench', 'bird', 'cat', 'dog', 'horse', 'sheep',
#             'cow', 'elephant', 'bear', 'zebra', 'giraffe', '', 'backpack', 'umbrella', '', '', 'handbag', 'tie',
#             'suitcase', 'frisbee', 'skis', 'snowboard', 'sports ball', 'kite', 'baseball bat', 'baseball glove',
#             'skateboard', 'surfboard', 'tennis racket', 'bottle', '', 'wine glass', 'cup', 'fork', 'knife', 'spoon',
#             'bowl', 'banana', 'apple', 'sandwich', 'orange', 'broccoli', 'carrot', 'hot dog', 'pizza', 'donut',
#             'cake', 'chair', 'couch', 'potted plant', 'bed', '', 'dining table', '', '', 'toilet', '', 'tv',
#             'laptop', 'mouse', 'remote', 'keyboard', 'cell phone', 'microwave', 'oven', 'toaster', 'sink',
#             'refrigerator', '', 'book', 'clock', 'vase', 'scissors', 'teddy bear', 'hair drier',
#             'toothbrush']

color_list = standard_to_bgr(STANDARD_COLORS)
# tf bilinear interpolation is different from any other's, just make do
input_sizes = [512, 640, 768, 896, 1024, 1280, 1280, 1536, 1536]
input_size = input_sizes[compound_coef] if force_input_size is None else force_input_size

# Load the model
# weights = 'weights/efficientdet-d0.pth'efficientdet-d0_19_7520
weights = 'efficientdet-d0_2_1623.pth'
model = EfficientDetBackbone(compound_coef=compound_coef, num_classes=len(obj_list),
                             ratios=anchor_ratios, scales=anchor_scales)
model.load_state_dict(torch.load(weights, map_location='cpu', weights_only=False))
model.requires_grad_(False)
model.eval()
# from super_gradients.training import models
# from super_gradients.common.object_names import Models
# model = models.get('yolo_nas_s', num_classes=5, checkpoint_path=r"C:\Users\jcw\.cache\torch\hub\checkpoints\yolo_nas_s_coco.pth")
# model.requires_grad_(False)
# model.eval()

if use_cuda:
    model = model.cuda()
if use_float16:
    model = model.half()

# Preprocessing utilities
regressBoxes = BBoxTransform()
clipBoxes = ClipBoxes()

def preprocess(ori_img, max_size=512, mean=(0.485, 0.456, 0.406), std=(0.229, 0.224, 0.225)):
    # Resize and pad the image to maintain aspect ratio
    h, w, _ = ori_img.shape
    scale = min(max_size / h, max_size / w)
    new_h, new_w = int(h * scale), int(w * scale)
    resized_img = cv2.resize(ori_img, (new_w, new_h))

    # Padding
    top, bottom = (max_size - new_h) // 2, (max_size - new_h + 1) // 2
    left, right = (max_size - new_w) // 2, (max_size - new_w + 1) // 2
    padded_img = cv2.copyMakeBorder(resized_img, top, bottom, left, right, cv2.BORDER_CONSTANT, value=(0, 0, 0))

    # Normalize the image
    normalized_img = (padded_img[..., ::-1] / 255 - mean) / std  # BGR -> RGB normalization

    # Add a batch dimension for the model
    framed_img = np.expand_dims(normalized_img, axis=0)
    
    # # Debug: print out image dimensions and scaling factors
    # print(f"Original Image Size: ({h}, {w}), Scaled Image Size: ({new_h}, {new_w}), Padding: Top-{top}, Left-{left}")

    # Return the image with meta information (including padding)
    framed_meta = {
        'height': h,
        'width': w,
        'scale': scale,
        'new_w': new_w,
        'new_h': new_h,
        'padding_w': left + right,
        'padding_h': top + bottom
    }

    return framed_img, framed_meta

def invert_affine(metas, preds):
    for i in range(len(preds)):
        meta = metas[i]
        if 'rois' not in preds[i] or preds[i]['rois'].ndim != 2:
            continue

        new_w, new_h = meta['new_w'], meta['new_h']
        old_w, old_h = meta['width'], meta['height']
        top, left = (meta['padding_h'] // 2, meta['padding_w'] // 2)

        preds[i]['rois'][:, [0, 2]] *= (old_w / new_w)
        preds[i]['rois'][:, [1, 3]] *= (old_h / new_h)

        preds[i]['rois'][:, [0, 2]] -= left
        preds[i]['rois'][:, [1, 3]] -= top

        preds[i]['rois'] = np.clip(preds[i]['rois'], 0, max(old_w, old_h))  # 防止越界
        preds[i]['rois'] = np.round(preds[i]['rois'])  # 避免浮点误差

    return preds


# Main loop to capture frames from webcam
while True:
    # Read a frame from the webcam
    ret, frame = cap.read()
    if not ret:
        print("Error: Failed to capture image.")
        break

    # Preprocess the frame (resize, normalize, etc.)
    ori_img = frame.copy()
    framed_img, framed_meta = preprocess(ori_img, max_size=input_size)

    # Prepare the input for the model (convert to tensor and move to GPU)
    x = torch.from_numpy(framed_img).to(torch.float32 if not use_float16 else torch.float16).permute(0, 3, 1, 2)
    
    if use_cuda:
        print(f"use_cuda:{use_cuda}")
        x = x.cuda()

    # Run inference
    with torch.no_grad():
        features, regression, classification, anchors = model(x)
        out = postprocess(x, anchors, regression, classification, regressBoxes, clipBoxes, threshold, iou_threshold)
        out = invert_affine([framed_meta], out)

        # Move the output tensors inside the dictionary to CPU if using CUDA
        if use_cuda:
            for i in range(len(out)):
                for key in out[i]:
                    if isinstance(out[i][key], torch.Tensor):
                        out[i][key] = out[i][key].cpu()

    # Display results
    for i in range(len(out)):
        if len(out[i]['rois']) == 0:
            continue

        for j in range(len(out[i]['rois'])):
            x1, y1, x2, y2 = out[i]['rois'][j].astype(int)
            class_id = out[i]['class_ids'][j]
            score = float(out[i]['scores'][j])
            obj = obj_list[class_id]

            print(f" Class ID: {class_id}, Label: {obj}, Score: {score} , Bounding Box: [{x1}, {y1}, {x2}, {y2}]")
            plot_one_box(ori_img, [x1, y1, x2, y2], label=obj, score=score, color=color_list[get_index_label(obj, obj_list)])

    # Display the processed frame with detections
    cv2.imshow('EfficientDet Inference', ori_img)

    # Press 'q' to exit the loop
    if cv2.waitKey(1) & 0xFF == ord('q'):
        break
# Out:
# use_cuda:True
# use_cuda:True
# use_cuda:True
# use_cuda:True
# use_cuda:True
# use_cuda:True
# use_cuda:True
# use_cuda:True
# use_cuda:True
# use_cuda:True
# use_cuda:True
# use_cuda:True
# use_cuda:True
# use_cuda:True
# use_cuda:True
# use_cuda:True
# use_cuda:True
# use_cuda:True
# use_cuda:True
# use_cuda:True
# use_cuda:True
# use_cuda:True
# use_cuda:True
# use_cuda:True
# use_cuda:True
# use_cuda:True
# use_cuda:True
# use_cuda:True
# use_cuda:True
# use_cuda:True
# use_cuda:True
# use_cuda:True
# use_cuda:True
# use_cuda:True
# use_cuda:True
# use_cuda:True
# use_cuda:True
# use_cuda:True
# use_cuda:True
# use_cuda:True
# use_cuda:True
# use_cuda:True
# use_cuda:True
# use_cuda:True
# use_cuda:True
# use_cuda:True
# use_cuda:True
# use_cuda:True
# use_cuda:True
# use_cuda:True
# use_cuda:True
# use_cuda:True
# use_cuda:True
# use_cuda:True
# use_cuda:True
# use_cuda:True
# use_cuda:True
# use_cuda:True
# use_cuda:True
# use_cuda:True
# use_cuda:True
# use_cuda:True
# use_cuda:True
# use_cuda:True
# use_cuda:True
# use_cuda:True
# use_cuda:True
# use_cuda:True
# use_cuda:True
# use_cuda:True
# use_cuda:True
# use_cuda:True
# use_cuda:True
# use_cuda:True
# use_cuda:True
# use_cuda:True
# use_cuda:True
# use_cuda:True
# use_cuda:True
# use_cuda:True
# use_cuda:True
# use_cuda:True
# use_cuda:True
# use_cuda:True
# use_cuda:True
# use_cuda:True
# use_cuda:True
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# Cell In[2], line 139
#     137 # Preprocess the frame (resize, normalize, etc.)
#     138 ori_img = frame.copy()
# --> 139 framed_img, framed_meta = preprocess(ori_img, max_size=input_size)
#     141 # Prepare the input for the model (convert to tensor and move to GPU)
#     142 x = torch.from_numpy(framed_img).to(torch.float32 if not use_float16 else torch.float16).permute(0, 3, 1, 2)
#
# Cell In[2], line 86, in preprocess(ori_img, max_size, mean, std)
#      83 padded_img = cv2.copyMakeBorder(resized_img, top, bottom, left, right, cv2.BORDER_CONSTANT, value=(0, 0, 0))
#      85 # Normalize the image
# ---> 86 normalized_img = (padded_img[..., ::-1] / 255 - mean) / std  # BGR -> RGB normalization
#      88 # Add a batch dimension for the model
#      89 framed_img = np.expand_dims(normalized_img, axis=0)
#
# KeyboardInterrupt:
# use_cuda:True
# 在当前单元格或上一个单元格中执行代码时 Kernel 崩溃。
#
# 请查看单元格中的代码，以确定故障的可能原因。
#
# 单击<a href='https://aka.ms/vscodeJupyterKernelCrash'>此处</a>了解详细信息。
#
# 有关更多详细信息，请查看 Jupyter <a href='command:jupyter.viewOutput'>log</a>。

# %%
import os
import torch
from torch.backends import cudnn
from matplotlib import colors
import cv2
import numpy as np
from backbone import EfficientDetBackbone
from efficientdet.utils import BBoxTransform, ClipBoxes
from utils.utils import postprocess, STANDARD_COLORS, standard_to_bgr, get_index_label, plot_one_box

# Setup
input_dir = r'F:\program\python\CowBoy\Yet-Another-EfficientDet-Pytorch\data_test\test\87'  # 设置图片文件夹路径
image_files = [f for f in os.listdir(input_dir) if f.endswith(('.jpg', '.png', '.jpeg'))]

# Model setup and loading
compound_coef = 0
force_input_size = None

anchor_ratios = [(1.0, 1.0), (1.4, 0.7), (0.7, 1.4)]
anchor_scales = [2 ** 0, 2 ** (1.0 / 3.0), 2 ** (2.0 / 3.0)]

threshold = 0.2
iou_threshold = 0.2

use_cuda = True
use_float16 = False
cudnn.fastest = True
cudnn.benchmark = True

obj_list = ['belt', 'sunglasses', 'boot', 'cowboy_hat', 'jacket']
color_list = standard_to_bgr(STANDARD_COLORS)

input_sizes = [512, 640, 768, 896, 1024, 1280, 1280, 1536, 1536]
input_size = input_sizes[compound_coef] if force_input_size is None else force_input_size

# 正确的写法是加载模型后再进行load_state_dict
weights = 'efficientdet-d0_2_1623.pth'
model = EfficientDetBackbone(compound_coef=compound_coef, num_classes=len(obj_list),
                             ratios=anchor_ratios, scales=anchor_scales)

# 先加载权重文件，再传给模型的 load_state_dict
state_dict = torch.load(weights, map_location='cpu')
model.load_state_dict(state_dict, strict=False)
model.requires_grad_(False)
model.eval()


if use_cuda:
    model = model.cuda()
if use_float16:
    model = model.half()

# Preprocessing utilities
regressBoxes = BBoxTransform()
clipBoxes = ClipBoxes()
def preprocess(ori_img, max_size=512, mean=(0.485, 0.456, 0.406), std=(0.229, 0.224, 0.225)):
    h, w, _ = ori_img.shape
    scale = min(max_size / h, max_size / w)
    new_h, new_w = int(h * scale), int(w * scale)
    resized_img = cv2.resize(ori_img, (new_w, new_h))
    top, bottom = (max_size - new_h) // 2, (max_size - new_h + 1) // 2
    left, right = (max_size - new_w) // 2, (max_size - new_w + 1) // 2
    padded_img = cv2.copyMakeBorder(resized_img, top, bottom, left, right, cv2.BORDER_CONSTANT, value=(0, 0, 0))
    normalized_img = (padded_img[..., ::-1] / 255 - mean) / std
    framed_img = np.expand_dims(normalized_img, axis=0)
    framed_meta = {'height': h, 'width': w, 'scale': scale, 'new_w': new_w, 'new_h': new_h,
                   'padding_w': left + right, 'padding_h': top + bottom}
    return framed_img, framed_meta

def invert_affine(metas, preds):
    for i in range(len(preds)):
        meta = metas[i]
        if 'rois' not in preds[i] or preds[i]['rois'].ndim != 2:
            continue
        new_w, new_h = meta['new_w'], meta['new_h']
        old_w, old_h = meta['width'], meta['height']
        top, left = (meta['padding_h'] // 2, meta['padding_w'] // 2)
        preds[i]['rois'][:, [0, 2]] *= (old_w / new_w)
        preds[i]['rois'][:, [1, 3]] *= (old_h / new_h)
        preds[i]['rois'][:, [0, 2]] -= left
        preds[i]['rois'][:, [1, 3]] -= top
        preds[i]['rois'] = np.clip(preds[i]['rois'], 0, max(old_w, old_h))
        preds[i]['rois'] = np.round(preds[i]['rois'])
    return preds

# Process images from the folder
for image_file in image_files:
    image_path = os.path.join(input_dir, image_file)
    ori_img = cv2.imread(image_path)
    if ori_img is None:
        print(f"Error: Unable to read image {image_path}")
        continue

    framed_img, framed_meta = preprocess(ori_img, max_size=input_size)

    # Prepare the input for the model (convert to tensor)
    x = torch.from_numpy(framed_img).cuda() if use_cuda else torch.from_numpy(framed_img)
    x = x.to(torch.float32 if not use_float16 else torch.float16).permute(0, 3, 1, 2)

    # Run inference
    with torch.no_grad():
        features, regression, classification, anchors = model(x)
        out = postprocess(x, anchors, regression, classification, regressBoxes, clipBoxes, threshold, iou_threshold)
        out = invert_affine([framed_meta], out)

    # Display results
    for i in range(len(out)):
        if len(out[i]['rois']) == 0:
            continue
        for j in range(len(out[i]['rois'])):
            x1, y1, x2, y2 = out[i]['rois'][j].astype(int)
            class_id = out[i]['class_ids'][j]
            score = float(out[i]['scores'][j])
            obj = obj_list[class_id]
            print(f" Class ID: {class_id}, Label: {obj}, Score: {score} , Bounding Box: [{x1}, {y1}, {x2}, {y2}]")
            plot_one_box(ori_img, [x1, y1, x2, y2], label=obj, score=score, color=color_list[get_index_label(obj, obj_list)])

    # Show the processed image with detections
    cv2.imshow(f'Inference on {image_file}', ori_img)

    # Press 'q' to exit after viewing an image
    if cv2.waitKey(0) & 0xFF == ord('q'):
        break

cv2.destroyAllWindows()
# Out:
# C:\Users\jcw\AppData\Local\Temp\ipykernel_22164\2885655994.py:42: FutureWarning: You are using `torch.load` with `weights_only=False` (the current default value), which uses the default pickle module implicitly. It is possible to construct malicious pickle data which will execute arbitrary code during unpickling (See https://github.com/pytorch/pytorch/blob/main/SECURITY.md#untrusted-models for more details). In a future release, the default value for `weights_only` will be flipped to `True`. This limits the functions that could be executed during unpickling. Arbitrary objects will no longer be allowed to be loaded via this mode unless they are explicitly allowlisted by the user via `torch.serialization.add_safe_globals`. We recommend you start setting `weights_only=True` for any use case where you don't have full control of the loaded file. Please open an issue on GitHub for any issues related to this experimental feature.
#   state_dict = torch.load(weights, map_location='cpu')
#  Class ID: 1, Label: sunglasses, Score: 0.3299347162246704 , Bounding Box: [227, 471, 297, 556]
#  Class ID: 4, Label: jacket, Score: 0.28635019063949585 , Bounding Box: [221, 481, 324, 565]
#  Class ID: 2, Label: boot, Score: 0.22753289341926575 , Bounding Box: [255, 497, 318, 564]
#  Class ID: 1, Label: sunglasses, Score: 0.3166274428367615 , Bounding Box: [902, 632, 963, 680]
#  Class ID: 3, Label: cowboy_hat, Score: 0.3146739900112152 , Bounding Box: [882, 730, 944, 801]
#  Class ID: 3, Label: cowboy_hat, Score: 0.31385233998298645 , Bounding Box: [563, 102, 622, 153]
#  Class ID: 4, Label: jacket, Score: 0.29824429750442505 , Bounding Box: [806, 655, 933, 741]
#  Class ID: 3, Label: cowboy_hat, Score: 0.28000709414482117 , Bounding Box: [819, 639, 882, 697]
#  Class ID: 1, Label: sunglasses, Score: 0.27407968044281006 , Bounding Box: [820, 664, 886, 782]
#  Class ID: 2, Label: boot, Score: 0.25480931997299194 , Bounding Box: [509, 479, 647, 541]
#  Class ID: 0, Label: belt, Score: 0.2540019750595093 , Bounding Box: [822, 599, 940, 785]
#  Class ID: 1, Label: sunglasses, Score: 0.24462765455245972 , Bounding Box: [548, 64, 632, 142]
#  Class ID: 0, Label: belt, Score: 0.23804929852485657 , Bounding Box: [849, 569, 1003, 664]
#  Class ID: 1, Label: sunglasses, Score: 0.2354816496372223 , Bounding Box: [758, 122, 885, 208]
#  Class ID: 1, Label: sunglasses, Score: 0.23408187925815582 , Bounding Box: [659, 71, 763, 103]
#  Class ID: 2, Label: boot, Score: 0.22076217830181122 , Bounding Box: [946, 597, 1022, 714]
#  Class ID: 4, Label: jacket, Score: 0.21507088840007782 , Bounding Box: [433, 462, 538, 527]
#  Class ID: 1, Label: sunglasses, Score: 0.20318575203418732 , Bounding Box: [850, 592, 967, 815]
#  Class ID: 0, Label: belt, Score: 0.20161406695842743 , Bounding Box: [921, 615, 1022, 747]
#  Class ID: 1, Label: sunglasses, Score: 0.20151911675930023 , Bounding Box: [567, 388, 631, 446]
#  Class ID: 1, Label: sunglasses, Score: 0.4907778203487396 , Bounding Box: [718, 707, 784, 757]
#  Class ID: 2, Label: boot, Score: 0.4350796639919281 , Bounding Box: [159, 325, 263, 500]
#  Class ID: 0, Label: belt, Score: 0.3800305724143982 , Bounding Box: [132, 301, 284, 588]
#  Class ID: 0, Label: belt, Score: 0.37016427516937256 , Bounding Box: [621, 695, 757, 937]
#  Class ID: 1, Label: sunglasses, Score: 0.31042617559432983 , Bounding Box: [689, 621, 754, 743]
#  Class ID: 1, Label: sunglasses, Score: 0.2912222445011139 , Bounding Box: [60, 369, 128, 424]
#  Class ID: 4, Label: jacket, Score: 0.2884683907032013 , Bounding Box: [41, 362, 153, 442]
#  Class ID: 2, Label: boot, Score: 0.25268399715423584 , Bounding Box: [278, 320, 403, 384]
#  Class ID: 3, Label: cowboy_hat, Score: 0.24052441120147705 , Bounding Box: [288, 309, 401, 369]
#  Class ID: 0, Label: belt, Score: 0.2398935705423355 , Bounding Box: [528, 657, 652, 898]
#  Class ID: 2, Label: boot, Score: 0.23795801401138306 , Bounding Box: [235, 268, 344, 320]
#  Class ID: 1, Label: sunglasses, Score: 0.23395797610282898 , Bounding Box: [128, 339, 383, 461]
#  Class ID: 3, Label: cowboy_hat, Score: 0.2328689843416214 , Bounding Box: [54, 367, 197, 439]
#  Class ID: 0, Label: belt, Score: 0.22389228641986847 , Bounding Box: [18, 435, 214, 624]
#  Class ID: 1, Label: sunglasses, Score: 0.22364811599254608 , Bounding Box: [263, 263, 384, 343]
#  Class ID: 2, Label: boot, Score: 0.22222933173179626 , Bounding Box: [94, 425, 195, 607]
#  Class ID: 1, Label: sunglasses, Score: 0.21422800421714783 , Bounding Box: [249, 322, 355, 380]
#  Class ID: 4, Label: jacket, Score: 0.21306219696998596 , Bounding Box: [83, 391, 197, 709]
#  Class ID: 1, Label: sunglasses, Score: 0.21269679069519043 , Bounding Box: [427, 409, 481, 527]
#  Class ID: 1, Label: sunglasses, Score: 0.20986193418502808 , Bounding Box: [0, 395, 271, 567]
#  Class ID: 2, Label: boot, Score: 0.20275306701660156 , Bounding Box: [39, 289, 176, 357]
#  Class ID: 3, Label: cowboy_hat, Score: 0.20116637647151947 , Bounding Box: [66, 316, 133, 366]
#  Class ID: 2, Label: boot, Score: 0.20083853602409363 , Bounding Box: [13, 328, 130, 394]
#  Class ID: 1, Label: sunglasses, Score: 0.5852397084236145 , Bounding Box: [646, 819, 860, 1022]
#  Class ID: 0, Label: belt, Score: 0.33598923683166504 , Bounding Box: [739, 748, 809, 1014]
#  Class ID: 1, Label: sunglasses, Score: 0.32043907046318054 , Bounding Box: [511, 150, 632, 447]
#  Class ID: 4, Label: jacket, Score: 0.279631108045578 , Bounding Box: [301, 55, 531, 455]
#  Class ID: 3, Label: cowboy_hat, Score: 0.2789337635040283 , Bounding Box: [247, 460, 359, 610]
#  Class ID: 2, Label: boot, Score: 0.2783411741256714 , Bounding Box: [609, 227, 718, 399]
#  Class ID: 0, Label: belt, Score: 0.273960679769516 , Bounding Box: [586, 273, 696, 541]
#  Class ID: 0, Label: belt, Score: 0.2700768709182739 , Bounding Box: [765, 486, 914, 636]
#  Class ID: 3, Label: cowboy_hat, Score: 0.2626548707485199 , Bounding Box: [431, 247, 692, 369]
#  Class ID: 1, Label: sunglasses, Score: 0.24801389873027802 , Bounding Box: [807, 884, 873, 930]
#  Class ID: 1, Label: sunglasses, Score: 0.23277801275253296 , Bounding Box: [504, 727, 732, 887]
#  Class ID: 1, Label: sunglasses, Score: 0.2320338934659958 , Bounding Box: [228, 558, 309, 684]
#  Class ID: 1, Label: sunglasses, Score: 0.22632350027561188 , Bounding Box: [485, 507, 738, 593]
#  Class ID: 4, Label: jacket, Score: 0.22396698594093323 , Bounding Box: [644, 662, 831, 749]
#  Class ID: 0, Label: belt, Score: 0.22150367498397827 , Bounding Box: [350, 549, 398, 640]
#  Class ID: 3, Label: cowboy_hat, Score: 0.21599072217941284 , Bounding Box: [747, 907, 872, 987]
#  Class ID: 2, Label: boot, Score: 0.215001180768013 , Bounding Box: [129, 56, 683, 321]
#  Class ID: 1, Label: sunglasses, Score: 0.21484139561653137 , Bounding Box: [252, 49, 398, 294]
#  Class ID: 2, Label: boot, Score: 0.20736533403396606 , Bounding Box: [721, 775, 842, 827]
#  Class ID: 2, Label: boot, Score: 0.20700737833976746 , Bounding Box: [729, 811, 825, 874]
#  Class ID: 1, Label: sunglasses, Score: 0.2066223919391632 , Bounding Box: [620, 166, 827, 251]
#  Class ID: 1, Label: sunglasses, Score: 0.205002099275589 , Bounding Box: [304, 515, 447, 778]
#  Class ID: 1, Label: sunglasses, Score: 0.20088480412960052 , Bounding Box: [366, 579, 430, 607]
