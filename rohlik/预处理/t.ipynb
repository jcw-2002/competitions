# %%
import pandas as pd


calendar = pd.read_csv('calendar.csv')
inventory = pd.read_csv('inventory.csv')

# %%
calendar
# Out:
#              date holiday_name  holiday  shops_closed  winter_school_holidays  \
# 0      2022-03-16         week        0             0                       0
# 1      2020-03-22         week        0             0                       0
# 2      2018-02-07         week        0             0                       0
# 3      2018-08-10         week        0             0                       0
# 4      2017-10-26         week        0             0                       0
# ...           ...          ...      ...           ...                     ...
# 23011  2019-04-20         week        1             0                       0
# 23012  2018-03-31         week        1             0                       0
# 23013  2017-04-15         week        1             0                       0
# 23014  2023-04-08         week        1             0                       0
# 23015  2024-03-30         week        1             0                       0
#
# ...

# %%
calendar['holiday_name'].value_counts()
# Out:
# holiday_name
# week                                                           22086
# Labour Day                                                        63
# 2nd Christmas Day                                                 63
# 1st Christmas Day                                                 63
# International womens day                                          63
# Christmas Eve                                                     63
# New Years Day                                                     63
# Good Friday                                                       42
# Easter Monday                                                     42
# Den boje za svobodu a demokracii                                  36
# Den vzniku samostatneho ceskoslovenskeho statu                    36
# Jan Hus                                                           36
# Den ceske statnosti                                               36
# ...

# %%
calendar['holiday_name'].fillna('week', inplace=True)
